# %% [markdown]
# # Tax function

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# types of programming
# OOP-----python
# Functional------R
# procedural-----SAS

# %%
# A more nuanced code for tax function
# built a dictionary which pairs each year to a list of threshholds.
# similarly bulit a dictionary which pairs for each year a list of tax rates

# %%
def Tax_function():

# %%
# for the data given, you can have a "for" loop by creating arrays for year and income(np arrays for both).

# %%
#PLOTS
grid_min = 0.0
grid_max = 250000
grid_size = 250

grid = np.linspace(grid_min, grid_max, grid_size)

# %%
grid
# Out:
# array([     0.        ,   1004.01606426,   2008.03212851,   3012.04819277,
#          4016.06425703,   5020.08032129,   6024.09638554,   7028.1124498 ,
#          8032.12851406,   9036.14457831,  10040.16064257,  11044.17670683,
#         12048.19277108,  13052.20883534,  14056.2248996 ,  15060.24096386,
#         16064.25702811,  17068.27309237,  18072.28915663,  19076.30522088,
#         20080.32128514,  21084.3373494 ,  22088.35341365,  23092.36947791,
#         24096.38554217,  25100.40160643,  26104.41767068,  27108.43373494,
#         28112.4497992 ,  29116.46586345,  30120.48192771,  31124.49799197,
#         32128.51405622,  33132.53012048,  34136.54618474,  35140.562249  ,
#         36144.57831325,  37148.59437751,  38152.61044177,  39156.62650602,
#         40160.64257028,  41164.65863454,  42168.6746988 ,  43172.69076305,
#         44176.70682731,  45180.72289157,  46184.73895582,  47188.75502008,
# ...

# %%
def f(x):
    return 4 * x + 2

# %%
q = f(grid)
q
# Out:
# array([2.00000000e+00, 4.01806426e+03, 8.03412851e+03, 1.20501928e+04,
#        1.60662570e+04, 2.00823213e+04, 2.40983855e+04, 2.81144498e+04,
#        3.21305141e+04, 3.61465783e+04, 4.01626426e+04, 4.41787068e+04,
#        4.81947711e+04, 5.22108353e+04, 5.62268996e+04, 6.02429639e+04,
#        6.42590281e+04, 6.82750924e+04, 7.22911566e+04, 7.63072209e+04,
#        8.03232851e+04, 8.43393494e+04, 8.83554137e+04, 9.23714779e+04,
#        9.63875422e+04, 1.00403606e+05, 1.04419671e+05, 1.08435735e+05,
#        1.12451799e+05, 1.16467863e+05, 1.20483928e+05, 1.24499992e+05,
#        1.28516056e+05, 1.32532120e+05, 1.36548185e+05, 1.40564249e+05,
#        1.44580313e+05, 1.48596378e+05, 1.52612442e+05, 1.56628506e+05,
#        1.60644570e+05, 1.64660635e+05, 1.68676699e+05, 1.72692763e+05,
#        1.76708827e+05, 1.80724892e+05, 1.84740956e+05, 1.88757020e+05,
#        1.92773084e+05, 1.96789149e+05, 2.00805213e+05, 2.04821277e+05,
# ...

# %%
# while loop
