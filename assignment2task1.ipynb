# %% [markdown]
# # Weekly assignment 2.1: Tax Function
#
# Australia has a progressive income taxes with several brackets.
# The tax function has the form
#
# $$
# \begin{cases}
# 0,&
# \text{ if income} \le \text{th}_1  \\
# (\text{income} - \text{th}_1)*\text{rate}_1,&
# \text{ if income} \in [\text{th}_1, \text{th}_2]  \\
# (\text{th}_2 - \text{th}_1)*\text{rate}_1 +
# (\text{income} - \text{th}_2)*\text{rate}_2,&
# \text{ if income} \in [\text{th}_2, \text{th}_3]  \\
# (\text{th}_2 - \text{th}_1)*\text{rate}_1 +
# (\text{th}_3-\text{th}_2)*\text{rate}_2 +
# (\text{income} - \text{th}_3)*\text{rate}_3,&
# \text{ if income} \in [\text{th}_3, \text{th}_4]  \\
# (\text{th}_2 - \text{th}_1)*\text{rate}_1 +
# (\text{th}_3-\text{th}_2)*\text{rate}_2 +
# (\text{th}_4-\text{th}_3)*\text{rate}_3 +
# (\text{income} - \text{th}_4)*\text{rate}_4,&
# \text{ if income} > \text{th}_4
# \end{cases}
# $$
#
# The values for the thresholds and the rates in the 15 year in the period
# between 2000 and 2015 are given in the table below.
#
# |Year|$ th_1 $|$ th_2 $|$ th_3 $|$ th_4 $|$ rate_1 $|$ rate_2 $|$ rate_3 $|$ rate_4 $|
# |:----:|:------------:|:------------:|:------------:|:------------:|:--------------:|:--------------:|:--------------:|:--------------:|
# |2000|6,000|20,000|50,000|60,000|0.17|0.30|0.42|0.47|
# |2001|6,000|20,000|50,000|60,000|0.17|0.30|0.42|0.47|
# |2002|6,000|20,000|50,000|60,000|0.17|0.30|0.42|0.47|
# |2003|6,000|21,600|52,000|62,500|0.17|0.30|0.42|0.47|
# |2004|6,000|21,600|58,000|70,000|0.17|0.30|0.42|0.47|
# |2005|6,000|21,600|63,000|95,000|0.15|0.30|0.42|0.47|
# |2006|6,000|25,000|75,000|150,000|0.15|0.30|0.40|0.45|
# |2007|6,000|30,000|75,000|150,000|0.15|0.30|0.40|0.45|
# |2008|6,000|34,000|80,000|180,000|0.15|0.30|0.40|0.45|
# |2009|6,000|35,000|80,000|180,000|0.15|0.30|0.38|0.45|
# |2010|6,000|37,000|80,000|180,000|0.15|0.30|0.37|0.45|
# |2011|6,000|37,000|80,000|180,000|0.15|0.30|0.37|0.45|
# |2012|18,200|37,000|80,000|180,000|0.19|0.325|0.37|0.45|
# |2013|18,200|37,000|80,000|180,000|0.19|0.325|0.37|0.45|
# |2014|18,200|37,000|80,000|180,000|0.19|0.325|0.37|0.45|
# |2015|18,200|37,000|80,000|180,000|0.19|0.325|0.37|0.45|

# %% [markdown]
# ## Task 1:
#
# - Write a function to calculate income tax from 2 input arguments: year and amount of income
# - Use **if/elif/then** statements for branching of the code
# - Run your function on the data provided

# %%
def taxfn(income, year):
    if year == 2000:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 20000:
            tax = (income - 6000)*0.17
        elif income > 20000 and income <= 50000:
            tax = (20000 - 6000)*0.17 + (income - 20000)*0.3
        elif income > 50000 and income <= 60000:
            tax = (20000 - 6000)*0.17 + (50000 - 20000)*0.3 + (income - 50000)*0.42
        elif income > 60000:
            tax = (20000 - 6000)*0.17 + (50000 - 20000)*0.3 + (60000 - 50000)*0.42 + (income - 60000)*0.47
    if year == 2001:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 20000:
            tax = (income - 6000)*0.17
        elif income > 20000 and income <= 50000:
            tax = (20000 - 6000)*0.17 + (income - 20000)*0.3
        elif income > 50000 and income <= 60000:
            tax = (20000 - 6000)*0.17 + (50000 - 20000)*0.3 + (income - 50000)*0.42
        elif income > 60000:
            tax = (20000 - 6000)*0.17 + (50000 - 20000)*0.3 + (60000 - 50000)*0.42 + (income - 60000)*0.47
    if year == 2002:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 20000:
            tax = (income - 6000)*0.17
        elif income > 20000 and income <= 50000:
            tax = (20000 - 6000)*0.17 + (income - 20000)*0.3
        elif income > 50000 and income <= 60000:
            tax = (20000 - 6000)*0.17 + (50000 - 20000)*0.3 + (income - 50000)*0.42
        elif income > 60000:
            tax = (20000 - 6000)*0.17 + (50000 - 20000)*0.3 + (60000 - 50000)*0.42 + (income - 60000)*0.47
    if year == 2003:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 21600:
            tax = (income - 6000)*0.17
        elif income > 21600 and income <= 52000:
            tax = (21600 - 6000)*0.17 + (income - 21600)*0.3
        elif income > 52000 and income <= 62500:
            tax = (21600 - 6000)*0.17 + (52000 - 21600)*0.3 + (income - 52000)*0.42
        elif income > 62500:
            tax = (21600 - 6000)*0.17 + (52000 - 21600)*0.3 + (62500 - 52000)*0.42 + (income - 62500)*0.47
    if year == 2004:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 21600:
            tax = (income - 6000)*0.17
        elif income > 21600 and income <= 58000:
            tax = (21600 - 6000)*0.17 + (income - 21600)*0.3
        elif income > 58000 and income <= 70000:
            tax = (21600 - 6000)*0.17 + (58000 - 21600)*0.3 + (income - 58000)*0.42
        elif income > 70000:
            tax = (21600 - 6000)*0.17 + (58000 - 21600)*0.3 + (70000 - 58000)*0.42 + (income - 70000)*0.47
    if year == 2005:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 21600:
            tax = (income - 6000)*0.15
        elif income > 21600 and income <= 63000:
            tax = (21600 - 6000)*0.15 + (income - 21600)*0.3
        elif income > 63000 and income <= 95000:
            tax = (21600 - 6000)*0.15 + (63000 - 21600)*0.3 + (income - 63000)*0.42
        elif income > 95000:
            tax = (21600 - 6000)*0.15 + (63000 - 21600)*0.3 + (95000 - 63000)*0.42 + (income - 95000)*0.47
    if year == 2006:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 25000:
            tax = (income - 6000)*0.15
        elif income > 25000 and income <= 75000:
            tax = (25000 - 6000)*0.15 + (income - 25000)*0.3
        elif income > 75000 and income <= 150000:
            tax = (25000 - 6000)*0.15 + (75000 - 25000)*0.3 + (income - 75000)*0.4
        elif income > 150000:
            tax = (25000 - 6000)*0.15 + (75000 - 25000)*0.3 + (150000 - 75000)*0.4 + (income - 150000)*0.45
    if year == 2007:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 30000:
            tax = (income - 6000)*0.15
        elif income > 30000 and income <= 75000:
            tax = (30000 - 6000)*0.15 + (income - 30000)*0.3
        elif income > 75000 and income <= 150000:
            tax = (30000 - 6000)*0.15 + (75000 - 30000)*0.3 + (income - 75000)*0.4
        elif income > 150000:
            tax = (30000 - 6000)*0.15 + (75000 - 30000)*0.3 + (150000 - 75000)*0.4 + (income - 150000)*0.45
    if year == 2008:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 34000:
            tax = (income - 6000)*0.15
        elif income > 34000 and income <= 80000:
            tax = (34000 - 6000)*0.15 + (income - 34000)*0.3
        elif income > 80000 and income <= 180000:
            tax = (34000 - 6000)*0.15 + (80000 - 34000)*0.3 + (income - 80000)*0.4
        elif income > 180000:
            tax = (34000 - 6000)*0.15 + (80000 - 34000)*0.3 + (180000 - 80000)*0.4 + (income - 180000)*0.45
    if year == 2009:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 35000:
            tax = (income - 6000)*0.15
        elif income > 35000 and income <= 80000:
            tax = (35000 - 6000)*0.15 + (income - 35000)*0.3
        elif income > 80000 and income <= 180000:
            tax = (35000 - 6000)*0.15 + (80000 - 35000)*0.3 + (income - 80000)*0.38
        elif income > 180000:
            tax = (35000 - 6000)*0.15 + (80000 - 35000)*0.3 + (180000 - 80000)*0.38 + (income - 180000)*0.45
    if year == 2010:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 37000:
            tax = (income - 6000)*0.15
        elif income > 37000 and income <= 80000:
            tax = (37000 - 6000)*0.15 + (income - 37000)*0.3
        elif income > 80000 and income <= 180000:
            tax = (37000 - 6000)*0.15 + (80000 - 37000)*0.3 + (income - 80000)*0.37
        elif income > 180000:
            tax = (37000 - 6000)*0.15 + (80000 - 37000)*0.3 + (180000 - 80000)*0.37 + (income - 180000)*0.45
    if year == 2011:
        if income <= 6000:
            tax = 0.0
        elif income > 6000 and income <= 37000:
            tax = (income - 6000)*0.15
        elif income > 37000 and income <= 80000:
            tax = (37000 - 6000)*0.15 + (income - 37000)*0.3
        elif income > 80000 and income <= 180000:
            tax = (37000 - 6000)*0.15 + (80000 - 37000)*0.3 + (income - 80000)*0.37
        elif income > 180000:
            tax = (37000 - 6000)*0.15 + (80000 - 37000)*0.3 + (180000 - 80000)*0.37 + (income - 180000)*0.45
    if year == 2012:
        if income <= 18200:
            tax = 0.0
        elif income > 18200 and income <= 37000:
            tax = (income - 18200)*0.19
        elif income > 37000 and income <= 80000:
            tax = (37000 - 18200)*0.19 + (income - 37000)*0.325
        elif income > 80000 and income <= 180000:
            tax = (37000 - 18200)*0.19 + (80000 - 37000)*0.325 + (income - 80000)*0.37
        elif income > 180000:
            tax = (37000 - 18200)*0.19 + (80000 - 37000)*0.325 + (180000 - 80000)*0.37 + (income - 180000)*0.45
    if year == 2013:
        if income <= 18200:
            tax = 0.0
        elif income > 18200 and income <= 37000:
            tax = (income - 18200)*0.19
        elif income > 37000 and income <= 80000:
            tax = (37000 - 18200)*0.19 + (income - 37000)*0.325
        elif income > 80000 and income <= 180000:
            tax = (37000 - 18200)*0.19 + (80000 - 37000)*0.325 + (income - 80000)*0.37
        elif income > 180000:
            tax = (37000 - 18200)*0.19 + (80000 - 37000)*0.325 + (180000 - 80000)*0.37 + (income - 180000)*0.45
    if year == 2014:
        if income <= 18200:
            tax = 0.0
        elif income > 18200 and income <= 37000:
            tax = (income - 18200)*0.19
        elif income > 37000 and income <= 80000:
            tax = (37000 - 18200)*0.19 + (income - 37000)*0.325
        elif income > 80000 and income <= 180000:
            tax = (37000 - 18200)*0.19 + (80000 - 37000)*0.325 + (income - 80000)*0.37
        elif income > 180000:
            tax = (37000 - 18200)*0.19 + (80000 - 37000)*0.325 + (180000 - 80000)*0.37 + (income - 180000)*0.45
    if year == 2015:
        if income <= 18200:
            tax = 0.0
        elif income > 18200 and income <= 37000:
            tax = (income - 18200)*0.19
        elif income > 37000 and income <= 80000:
            tax = (37000 - 18200)*0.19 + (income - 37000)*0.325
        elif income > 80000 and income <= 180000:
            tax = (37000 - 18200)*0.19 + (80000 - 37000)*0.325 + (income - 80000)*0.37
        elif income > 180000:
            tax = (37000 - 18200)*0.19 + (80000 - 37000)*0.325 + (180000 - 80000)*0.37 + (income - 180000)*0.45
    return tax

# %%
taxfn(181000,2015)
# Out:
# 54997.0

# %%
#This is a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-7a998c8b3b7a> in <module>()
#       1 year = 2000
#       2 income = 42400
# ----> 3 taxfn()
#
# TypeError: taxfn() missing 2 required positional arguments: 'income' and 'year'

# %%
# draft implementation for year 2000 to get you started

income=54780.0

if income <= 6000:
    tax = 0.0
elif income > 6000 and income <= 20000:
    tax = (income-6000)*0.17
elif income > 20000 and income <= 50000:
    tax = (income-20000)*0.30
elif income > 50000 and income <= 60000:
    tax = (income-50000)*0.42
elif income > 60000:
    tax = (income-60000)*0.47

print('tax(%1.2f) = %1.2f AUD' % (income,tax))
# Out:
# tax(54780.00) = 2007.60 AUD

# %%
# run your function on the following data

year = 2000
income = 42400
taxfn(42400,2000)

year = 2010
income = 58300
taxfn(58300,2010)

year = 2015
income = 82710
taxfn(82710,2015)

year = 2012
income = 120340
taxfn(120340,2012)

year = 2001
income = 431400
taxfn(431400,2001)

year = 2003
income = 41870
taxfn(41870,2003)

year = 2009
income = 1407790
taxfn(1407790, 2009)
# Out:
# tax(income = 42400.00 and year = 2000) = 9100.00 AUD
# tax(income = 58300.00 and year = 2010) = 11040.00 AUD
# tax(income = 82710.00 and year = 2015) = 18549.70 AUD
# tax(income = 120340.00 and year = 2012) = 32472.80 AUD
# tax(income = 431400.00 and year = 2001) = 190138.00 AUD
# tax(income = 41870.00 and year = 2003) = 8733.00 AUD
# tax(income = 1407790.00 and year = 2009) = 608355.50 AUD

# %% [markdown]
# ## Task 2:
#
# - Make the plot of the tax functions using the starter code below
# - Replace the @@@ symbols with appropriate code
# - The plot should show 15 different lines in the income - tax space

# %%
#let's make a plot as well
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 8]
K = 250 #number of points in the income grid
max_inc = 250000 #maximum income
inc = [k * max_inc / (K-1) for k in range(K)] # grid over income
tax1 = [0,]*K
for year in [2000+i for i in range(16)]:
    for j in range(K):
        income = inc[j]
        tax1[j] = taxfn(income,year)
        plt.plot(inc,tax1,label="year %d" %year)
plt.xlabel('inc')
plt.ylabel('tax')
plt.title('income_tax 2000-2015')
plt.show()

# %%
#let's make a plot as well
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 8]
K = 250 #number of points in the income grid
max_inc = 250000 #maximum income
inc = [k * 1000 / (K-1) for k in range(250000)] # grid over income

# %%
#let's make a plot as well
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 8]
K = 250 #number of points in the income grid
max_inc = 250000 #maximum income
inc = [k * @@ / (K-1) for k in range(@@)] # grid over income
tax = [0,]*K
for year in [@@@ for i in range(@@)]:
    for j in range(@@):
        income = inc[j]
        tax[j] = @@@
    plt.plot(inc,tax,label="year %d" % year)
plt.xlabel('inc')
plt.ylabel('tax')
plt.show()

# %% [markdown]
# ## Task 3 $ ^\star $:
#
# - Write another implementation of the same function based on the **while** loop
# - Hint: precompute thresholds and rates based on the year, and run a while loop to compute the amount of tax in stages
# - Run the new implementation on the same data as above and verify it returns the same answers
# - Discuss the advantages and disadvantages of the two implementations

# %%
def tax(income, year):
    if year in (2000, 2001, 2002):
        th = [6000, 20000, 50000, 60000]
        rt = [0.17, 0.3, 0.42, 0.47]
    elif year==2003:
        th = [6000, 21600, 52000, 62500]
        rt = [0.17, 0.30, 0.42, 0.47]
    elif year == 2004:
        th = [6000, 21600, 58000, 70000]
        rt = [0.17, 0.30 ,0.42, 0.47]
    elif year == 2005:
        th = [0,6000,21600,63000,95000]
        rt = [0.0,0.15,0.30,0.42,0.47]
    elif year == 2006:
        th = [0,6000,25000,75000,150000]
        rt = [0.0,0.15,0.30,0.40,0.45]
    elif year == 2007:
        th = [0,6000,30000,75000,150000]
        rt = [0.0,0.15,0.30,0.40,0.45]
    elif year == 2008:
        th = [0,6000,34000,80000,180000]
        rt = [0.0,0.15,0.30,0.40,0.45]
    elif year == 2009:
        th = [0,6000,35000,80000,180000]
        rt = [0.0,0.15,0.30,0.38,0.45]
    elif year in (2010,2011):
        th = [0,6000,37000,80000,180000]
        rt = [0.0,0.15,0.30,0.37,0.45]
    elif year in (2012,2013,2014,2015):
        th = [0,18200,37000,80000,180000]
        rt = [0.0,0.19,0.325,0.37,0.45]
    
    tax = 0
    i = 1
    while income>=th[i]:
        tax += (th[i] - th[i-1])*rt[i-1]
        i += 1
        if i > 4: break
    tax += (income - th[i-1])*rt[i-1]
    return tax

# %%
tax(40000, 2000)
# Out:
# 8380.0
